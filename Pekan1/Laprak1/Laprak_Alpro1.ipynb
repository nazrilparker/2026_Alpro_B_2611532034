# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMROGRAMAN**
#
# **“Perkenalan Mata kuliah, Instalasi VS Code, Jupyter Notebook, Github”**
#
# **Disusun Oleh :**
#
# **Muhammad Nazril Fandhi**
#
# **2611532034**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Perkenalan Mata kuliah, Instalasi VS Code, Jupyter Notebook, Github yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma Pemrograman. Praktikum ini berfokus pada pembahasan dasar python, penggunaan vscode untuk membuat dan menjalankan program, serta menghubungkan proyek dengan GitHub untuk menyimpan dan mengelola kode.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep PENGENALAN PYTHON, VS CODE, DAN KONEKSI KE GITHUB pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Python merupakan salah satu bahasa pemrograman yang banyak digunakan karena memiliki sintaks yang sederhana dan mudah dipahami. Dalam proses pemrograman, Visual Studio Code dapat digunakan untuk menulis, menjalankan, dan mengembangkan kode Python. Jupyter Notebook adalah aplikasi berbasis web yang digunakan untuk menulis kode program secara interaktif. Selain itu, GitHub membantu menyimpan serta mengelola kode secara online. Oleh karena itu, pemahaman tentang Python, VS Code, dan GitHub penting sebagai dasar untuk membuat dan mengembangkan program dengan lebih terstruktur.
#
# ##### 1.2 Tujuan
# 1. Memahami dasar-dasar bahasa pemrograman Python.
# 2. Mengetahui cara menggunakan VS Code untuk membuat program.
# 3. Memahami cara menjalankan program Python melalui VS Code.
# 4. Mengetahui cara menghubungkan VS Code dengan GitHub.
# 5. Memahami cara menyimpan dan mengelola kode menggunakan GitHub.
#
# #### 1.3 Manfaat
# 1. Memiliki dasar yang kuat untuk mempelajari struktur data.
# 2. Mampu membuat dan menguji program Python sederhana.
# 3. Terbiasa menggunakan lingkungan pengembangan.
# 4. Memahami dasar version control dan pengelolaan source code.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Python
#
# Python adalah bahasa pemrograman tingkat tinggi yang mendukung pemrograman prosedural dan berorientasi objek. Sintaksnya ringkas dan mudah dibaca.
#
# 2. Visual Studio Code (VS Code)
#
# Visual Studio Code merupakan editor kode yang dapat digunakan untuk menulis, menjalankan, dan melakukan debugging program.
#
# 3. Git dan GitHub
#
# Git dan GitHub merupakan layanan daring untuk menyimpan repository Git dan mendukung kolaborasi.
#
# 4. Jupyter Notebook
#
# Jupyter Notebook adalah aplikasi berbasis web yang digunakan untuk menulis dan menjalankan kode program secara interaktif.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Alpro_B_2611532034"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini " + "dibuat oleh " + "Muhammad Nazril Fandhi " 
+ "2611532034")

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama digunakan untuk memberikan komentar pada program. Komentar ini hanya sebagai keterangan agar kita lebih mudah memahami isi kode dan tidak ikut dijalankan oleh Python.
# 2. Bagian kedua menggunakan print() untuk menampilkan tulisan ke layar. Jadi, setiap perintah print() akan menghasilkan output sesuai dengan teks yang kita masukkan.
# 3. Bagian ketiga digunakan untuk menggabungkan tulisan dengan nama dan NIM. Tanda + digunakan untuk menyambungkan beberapa teks sehingga hasilnya bisa ditampilkan sebagai satu kalimat.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal : buatlah sebuah file program python bebas**

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Alpro_B_2611532034"

# %%
print ("====== BIODATA MAHASISWA ======")
print ("Nama:", "Muhammad Nazril Fandhi")
print ("NIM:", "2611532034")
print ("Program Studi:", "Informatika")
print ("Kelas:", "B")
print ("Fakultas:", "Teknologi Informasi")
print ("====== UNIVERSITAS ANDALAS ======")
print (" ")
print (" ")
print("             /\\")
print("            /  \\")
print("           /    \\")
print("          /______\\")
print("         /|      |\\")
print("        / |      | \\")
print("       /__|______|__\\")
print("       |            |")
print("       |   ____     |")
print("       |  |    |    |")
print("       |  | [] |    |")
print("       |  |____|    |")
print("       |            |")
print("       | []      [] |")
print("       |____________|")

# %% [markdown]
# **Penjelasan :** Program ini menggunakan perintah print() untuk menampilkan informasi biodata mahasiswa, seperti nama, NIM, program studi, fakultas, dan kelas. Selain itu, print() juga digunakan untuk menyusun karakter secara bertahap.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python memiliki sintaks yang sederhana dan dapat digunakan untuk membangun program secara terstruktur. Konsep dasar seperti variabel, tipe data, class, object, method, list, dan perulangan merupakan bekal penting sebelum mempelajari struktur data yang lebih kompleks. VS Code atau Jupyter Notebook membantu proses penulisan dan pengujian program, sedangkan Git dan GitHub dapat digunakan untuk menyimpan serta mengelola perubahan source code. Implementasi class mahasiswa menunjukkan bagaimana data dapat dikelompokkan dan diproses secara sistematis. Dengan memahami dasar-dasar tersebut, mahasiswa memiliki bekal untuk mengikuti praktikum struktur data berikutnya.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, “Python 3 Documentation,” Python.org, 2026. [Online]. Tersedia: https://docs.python.org/3/
#
# [2] Microsoft, “Visual Studio Code Documentation,” Microsoft Learn, 2026. [Online]. Tersedia: https://code.visualstudio.com/docs
#
# [3] GitHub, “GitHub Documentation,” GitHub Docs, 2026. [Online]. Tersedia: https://docs.github.com/
#
# [4] Project Jupyter, "Jupyter Notebook Documentation" Project Jupyter, 2024. [Online]. Tersedia: https://docs.jupyter.org/en/latest/
